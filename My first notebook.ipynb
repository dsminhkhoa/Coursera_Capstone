# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Huynh Minh Khoa**
# My desired occupation: Data Science in Healthcare

# %% [markdown]
# _I am a pharmacist. I am interested in data science because i want to contribute more and more in the development of Health Care in my country, Viet Nam._

# %% [markdown]
# ### Calculate 1 + 100

# %%
1 + 100
# Out:
# 101

# %% [markdown]
# http://datascience.berkeley.edu/about/what-is-data-science
# 1. What is Data Science?
#  - Capture
#  - Maintain
#  - Process
#  - Analyze
#  - Communicate
# 2. Why Become a Data Scientist?
#  - High salary

# %% [markdown]
# ![alexa-funny-670x335.jpg](attachment:alexa-funny-670x335.jpg)

# %% [markdown]
# # THANKS YOU SO MUCH!
